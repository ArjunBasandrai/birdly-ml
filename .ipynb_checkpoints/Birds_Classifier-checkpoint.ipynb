# %% [markdown]
# # 1. Importing required libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

# %% [markdown]
# # 2. Loading the dataset

# %% [markdown]
# Splitting the dataset into **Training Set**, **Cross Validation Set** and **Test Set** as:
#
# - $\text{Training Set} = \text{80%}$,<br>
# - $\text{Validation Set} = \text{10%}$, <br>
# - $\text{Test Set} = \text{10%}$
#
# Image dimnesions used are `224 x 224` and batch size of `8`

# %%
image_size = 224
batch_size = 8

train_ds = tf.keras.utils.image_dataset_from_directory(
  'training_set/',
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(image_size, image_size),
  batch_size=batch_size)


val_ds = tf.keras.utils.image_dataset_from_directory(
  'training_set/',
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(image_size, image_size),
  batch_size=batch_size)
# Out:
# Found 22620 files belonging to 25 classes.
# Using 18096 files for training.
# Found 22620 files belonging to 25 classes.
# Using 4524 files for validation.

# %%
class_names = train_ds.class_names

# %%
val_batches = tf.data.experimental.cardinality(val_ds)
test_ds = val_ds.take(val_batches // 2)
val_ds = val_ds.skip(val_batches // 2)

# %% [markdown]
# # 3. Configuring dataset for better performance

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # 4. Preparing the model

# %% [markdown]
# ### Data Augmentation layer

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])

# %% [markdown]
# ### Importing the base model (VGG16)

# %%
base_model = tf.keras.applications.VGG16(input_shape=(224,224,3),
                                               include_top=False,
                                               weights='imagenet')
base_model.trainable = False

# %% [markdown]
# ### Creating the model architecture

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./127.5, offset=-1),
    data_augmentation,
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(256,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(32,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(len(class_names))
])

# %% [markdown]
# # 5. Compiling the model

# %% [markdown]
# Using `SparseCategoricalCrossentropy` loss and `learning rate = 0.001`

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# # 6. Training the model

# %% [markdown]
# Using:
# - Early Stopping to stop training when validation accuracy has stopped improving
# - Saving weights on all iterations
# - Saving weights if they produce the best validaiton accuracy
# - Saving the trained model
#
# Initial number of `epochs = 60`

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=4, min_delta=0.001, restore_best_weights=True)

cp = tf.keras.callbacks.ModelCheckpoint(filepath="training_weights/checkpoints/cp-{epoch}.ckpt",
                                                 save_weights_only=True,
                                                 verbose=1)

best = tf.keras.callbacks.ModelCheckpoint(filepath="training_weights/best/model_best_val_accuracy.ckpt",
                                         save_weights_only=True,
                                         mointor="val_accuracy",
                                         mode="max",
                                         save_best_only=True)
history = model.fit(train_ds,
                    epochs=60,
                    validation_data=val_ds,
                   callbacks=[es,cp,best])
model.save('training_weights/models/vgg16_modified.h5')
# Out:
# Epoch 1/60
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 2262/2262 [==============================] - ETA: 0s - loss: 2.8346 - accuracy: 0.1335
# Epoch 1: saving model to training_weights/checkpoints\cp-1.ckpt
# 2262/2262 [==============================] - 270s 116ms/step - loss: 2.8346 - accuracy: 0.1335 - val_loss: 2.2059 - val_accuracy: 0.2996
# Epoch 2/60
# 2262/2262 [==============================] - ETA: 0s - loss: 2.2983 - accuracy: 0.2872
# Epoch 2: saving model to training_weights/checkpoints\cp-2.ckpt
# 2262/2262 [==============================] - 262s 116ms/step - loss: 2.2983 - accuracy: 0.2872 - val_loss: 1.7472 - val_accuracy: 0.4354
# Epoch 3/60
# 2262/2262 [==============================] - ETA: 0s - loss: 2.0470 - accuracy: 0.3615
# Epoch 3: saving model to training_weights/checkpoints\cp-3.ckpt
# 2262/2262 [==============================] - 261s 115ms/step - loss: 2.0470 - accuracy: 0.3615 - val_loss: 1.5564 - val_accuracy: 0.5018
# Epoch 4/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.9324 - accuracy: 0.4091
# Epoch 4: saving model to training_weights/checkpoints\cp-4.ckpt
# 2262/2262 [==============================] - 261s 115ms/step - loss: 1.9324 - accuracy: 0.4091 - val_loss: 1.4403 - val_accuracy: 0.5628
# Epoch 5/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.8242 - accuracy: 0.4446
# Epoch 5: saving model to training_weights/checkpoints\cp-5.ckpt
# 2262/2262 [==============================] - 259s 114ms/step - loss: 1.8242 - accuracy: 0.4446 - val_loss: 1.3697 - val_accuracy: 0.5889
# Epoch 6/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.7570 - accuracy: 0.4712
# Epoch 6: saving model to training_weights/checkpoints\cp-6.ckpt
# 2262/2262 [==============================] - 256s 113ms/step - loss: 1.7570 - accuracy: 0.4712 - val_loss: 1.3736 - val_accuracy: 0.5876
# Epoch 7/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.6961 - accuracy: 0.4951
# Epoch 7: saving model to training_weights/checkpoints\cp-7.ckpt
# 2262/2262 [==============================] - 260s 115ms/step - loss: 1.6961 - accuracy: 0.4951 - val_loss: 1.2692 - val_accuracy: 0.6142
# Epoch 8/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.6671 - accuracy: 0.5043
# Epoch 8: saving model to training_weights/checkpoints\cp-8.ckpt
# 2262/2262 [==============================] - 260s 115ms/step - loss: 1.6671 - accuracy: 0.5043 - val_loss: 1.2080 - val_accuracy: 0.6354
# Epoch 9/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.6131 - accuracy: 0.5202
# Epoch 9: saving model to training_weights/checkpoints\cp-9.ckpt
# 2262/2262 [==============================] - 262s 116ms/step - loss: 1.6131 - accuracy: 0.5202 - val_loss: 1.1695 - val_accuracy: 0.6527
# Epoch 10/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.5740 - accuracy: 0.5334
# Epoch 10: saving model to training_weights/checkpoints\cp-10.ckpt
# 2262/2262 [==============================] - 260s 115ms/step - loss: 1.5740 - accuracy: 0.5334 - val_loss: 1.1620 - val_accuracy: 0.6695
# Epoch 11/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.5519 - accuracy: 0.5493
# Epoch 11: saving model to training_weights/checkpoints\cp-11.ckpt
# 2262/2262 [==============================] - 259s 114ms/step - loss: 1.5519 - accuracy: 0.5493 - val_loss: 1.1232 - val_accuracy: 0.6664
# Epoch 12/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.5281 - accuracy: 0.5615
# Epoch 12: saving model to training_weights/checkpoints\cp-12.ckpt
# 2262/2262 [==============================] - 259s 115ms/step - loss: 1.5281 - accuracy: 0.5615 - val_loss: 1.0984 - val_accuracy: 0.6708
# Epoch 13/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.5063 - accuracy: 0.5674
# Epoch 13: saving model to training_weights/checkpoints\cp-13.ckpt
# 2262/2262 [==============================] - 259s 114ms/step - loss: 1.5063 - accuracy: 0.5674 - val_loss: 1.1025 - val_accuracy: 0.6748
# Epoch 14/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.4768 - accuracy: 0.5712
# Epoch 14: saving model to training_weights/checkpoints\cp-14.ckpt
# 2262/2262 [==============================] - 259s 114ms/step - loss: 1.4768 - accuracy: 0.5712 - val_loss: 1.0810 - val_accuracy: 0.6854
# Epoch 15/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.4690 - accuracy: 0.5814
# Epoch 15: saving model to training_weights/checkpoints\cp-15.ckpt
# 2262/2262 [==============================] - 260s 115ms/step - loss: 1.4690 - accuracy: 0.5814 - val_loss: 1.0876 - val_accuracy: 0.6801
# Epoch 16/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.4476 - accuracy: 0.5871
# Epoch 16: saving model to training_weights/checkpoints\cp-16.ckpt
# 2262/2262 [==============================] - 259s 115ms/step - loss: 1.4476 - accuracy: 0.5871 - val_loss: 1.0680 - val_accuracy: 0.6876
# Epoch 17/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.4319 - accuracy: 0.5972
# Epoch 17: saving model to training_weights/checkpoints\cp-17.ckpt
# 2262/2262 [==============================] - 260s 115ms/step - loss: 1.4319 - accuracy: 0.5972 - val_loss: 1.0442 - val_accuracy: 0.6960
# Epoch 18/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.4322 - accuracy: 0.5989
# Epoch 18: saving model to training_weights/checkpoints\cp-18.ckpt
# 2262/2262 [==============================] - 259s 114ms/step - loss: 1.4322 - accuracy: 0.5989 - val_loss: 1.0598 - val_accuracy: 0.6854
# Epoch 19/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.4181 - accuracy: 0.5981
# Epoch 19: saving model to training_weights/checkpoints\cp-19.ckpt
# 2262/2262 [==============================] - 259s 114ms/step - loss: 1.4181 - accuracy: 0.5981 - val_loss: 1.0323 - val_accuracy: 0.6973
# Epoch 20/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.3954 - accuracy: 0.6059
# Epoch 20: saving model to training_weights/checkpoints\cp-20.ckpt
# 2262/2262 [==============================] - 258s 114ms/step - loss: 1.3954 - accuracy: 0.6059 - val_loss: 1.0146 - val_accuracy: 0.7013
# Epoch 21/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.3891 - accuracy: 0.6133
# Epoch 21: saving model to training_weights/checkpoints\cp-21.ckpt
# 2262/2262 [==============================] - 258s 114ms/step - loss: 1.3891 - accuracy: 0.6133 - val_loss: 1.0162 - val_accuracy: 0.7035
# Epoch 22/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.3882 - accuracy: 0.6121
# Epoch 22: saving model to training_weights/checkpoints\cp-22.ckpt
# 2262/2262 [==============================] - 259s 114ms/step - loss: 1.3882 - accuracy: 0.6121 - val_loss: 1.0081 - val_accuracy: 0.7053
# Epoch 23/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.3516 - accuracy: 0.6210
# Epoch 23: saving model to training_weights/checkpoints\cp-23.ckpt
# 2262/2262 [==============================] - 259s 115ms/step - loss: 1.3516 - accuracy: 0.6210 - val_loss: 1.0259 - val_accuracy: 0.7142
# Epoch 24/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.3648 - accuracy: 0.6195
# Epoch 24: saving model to training_weights/checkpoints\cp-24.ckpt
# 2262/2262 [==============================] - 259s 114ms/step - loss: 1.3648 - accuracy: 0.6195 - val_loss: 0.9789 - val_accuracy: 0.7208
# Epoch 25/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.3516 - accuracy: 0.6159
# Epoch 25: saving model to training_weights/checkpoints\cp-25.ckpt
# 2262/2262 [==============================] - 257s 114ms/step - loss: 1.3516 - accuracy: 0.6159 - val_loss: 0.9845 - val_accuracy: 0.7058
# Epoch 26/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.3469 - accuracy: 0.6224
# Epoch 26: saving model to training_weights/checkpoints\cp-26.ckpt
# 2262/2262 [==============================] - 256s 113ms/step - loss: 1.3469 - accuracy: 0.6224 - val_loss: 0.9673 - val_accuracy: 0.7164
# Epoch 27/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.3393 - accuracy: 0.6285
# Epoch 27: saving model to training_weights/checkpoints\cp-27.ckpt
# 2262/2262 [==============================] - 252s 111ms/step - loss: 1.3393 - accuracy: 0.6285 - val_loss: 0.9750 - val_accuracy: 0.7168
# Epoch 28/60
# 2262/2262 [==============================] - ETA: 0s - loss: 1.3162 - accuracy: 0.6275
# Epoch 28: saving model to training_weights/checkpoints\cp-28.ckpt
# 2262/2262 [==============================] - 253s 112ms/step - loss: 1.3162 - accuracy: 0.6275 - val_loss: 0.9678 - val_accuracy: 0.7181

# %% [markdown]
# # 7. Fine-tuning the trained model

# %% [markdown]
# ### Making the last 7 layers of base_model trainable

# %%
base_model.trainable = True
for layer in base_model.layers[:12]:
    layer.trainable = False

# %% [markdown]
# ### Compiling the model again

# %% [markdown]
# Using `SparseCategoricalCrossentropy` loss and `learning rate = 1e-5`

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training again for fine-tuning

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=4,min_delta=0.001,restore_best_weights=True)

cp = tf.keras.callbacks.ModelCheckpoint(filepath="ft_weights/checkpoints/cp-{epoch}.ckpt",
                                                 save_weights_only=True,
                                                 verbose=1)

best = tf.keras.callbacks.ModelCheckpoint(filepath="ft_weights/best/model_best_val_loss.ckpt",
                                         save_weights_only=True,
                                         mointor="val_accuracy",
                                         mode="max",
                                         save_best_only=True)
fhistory = model.fit(train_ds,
                    epochs=history.epoch[-1]+40,
                    validation_data=val_ds,
                    initial_epoch=history.epoch[-1],
                    callbacks=[es,cp,best])

model.save('ft_weights/models/vgg16_modified.h5')
# Out:
# Epoch 28/67
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 2262/2262 [==============================] - ETA: 0s - loss: 1.1140 - accuracy: 0.6951
# Epoch 28: saving model to ft_weights/checkpoints\cp-28.ckpt
# 2262/2262 [==============================] - 364s 159ms/step - loss: 1.1140 - accuracy: 0.6951 - val_loss: 0.6325 - val_accuracy: 0.8137
# Epoch 29/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.8730 - accuracy: 0.7632
# Epoch 29: saving model to ft_weights/checkpoints\cp-29.ckpt
# 2262/2262 [==============================] - 360s 159ms/step - loss: 0.8730 - accuracy: 0.7632 - val_loss: 0.5588 - val_accuracy: 0.8389
# Epoch 30/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.7334 - accuracy: 0.8054
# Epoch 30: saving model to ft_weights/checkpoints\cp-30.ckpt
# 2262/2262 [==============================] - 362s 160ms/step - loss: 0.7334 - accuracy: 0.8054 - val_loss: 0.4923 - val_accuracy: 0.8575
# Epoch 31/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.6331 - accuracy: 0.8277
# Epoch 31: saving model to ft_weights/checkpoints\cp-31.ckpt
# 2262/2262 [==============================] - 361s 160ms/step - loss: 0.6331 - accuracy: 0.8277 - val_loss: 0.4742 - val_accuracy: 0.8752
# Epoch 32/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.5729 - accuracy: 0.8447
# Epoch 32: saving model to ft_weights/checkpoints\cp-32.ckpt
# 2262/2262 [==============================] - 364s 161ms/step - loss: 0.5729 - accuracy: 0.8447 - val_loss: 0.4602 - val_accuracy: 0.8748
# Epoch 33/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.5395 - accuracy: 0.8551
# Epoch 33: saving model to ft_weights/checkpoints\cp-33.ckpt
# 2262/2262 [==============================] - 364s 161ms/step - loss: 0.5395 - accuracy: 0.8551 - val_loss: 0.4237 - val_accuracy: 0.8836
# Epoch 34/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.4781 - accuracy: 0.8738
# Epoch 34: saving model to ft_weights/checkpoints\cp-34.ckpt
# 2262/2262 [==============================] - 364s 161ms/step - loss: 0.4781 - accuracy: 0.8738 - val_loss: 0.4160 - val_accuracy: 0.8951
# Epoch 35/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.4420 - accuracy: 0.8849
# Epoch 35: saving model to ft_weights/checkpoints\cp-35.ckpt
# 2262/2262 [==============================] - 365s 161ms/step - loss: 0.4420 - accuracy: 0.8849 - val_loss: 0.4026 - val_accuracy: 0.8903
# Epoch 36/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.4082 - accuracy: 0.8921
# Epoch 36: saving model to ft_weights/checkpoints\cp-36.ckpt
# 2262/2262 [==============================] - 364s 161ms/step - loss: 0.4082 - accuracy: 0.8921 - val_loss: 0.3575 - val_accuracy: 0.9062
# Epoch 37/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.3690 - accuracy: 0.8999
# Epoch 37: saving model to ft_weights/checkpoints\cp-37.ckpt
# 2262/2262 [==============================] - 364s 161ms/step - loss: 0.3690 - accuracy: 0.8999 - val_loss: 0.4135 - val_accuracy: 0.8991
# Epoch 38/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.3556 - accuracy: 0.9071
# Epoch 38: saving model to ft_weights/checkpoints\cp-38.ckpt
# 2262/2262 [==============================] - 364s 161ms/step - loss: 0.3556 - accuracy: 0.9071 - val_loss: 0.3536 - val_accuracy: 0.9027
# Epoch 39/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.3373 - accuracy: 0.9106
# Epoch 39: saving model to ft_weights/checkpoints\cp-39.ckpt
# 2262/2262 [==============================] - 363s 160ms/step - loss: 0.3373 - accuracy: 0.9106 - val_loss: 0.3427 - val_accuracy: 0.9186
# Epoch 40/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.9179
# Epoch 40: saving model to ft_weights/checkpoints\cp-40.ckpt
# 2262/2262 [==============================] - 361s 159ms/step - loss: 0.3119 - accuracy: 0.9179 - val_loss: 0.4027 - val_accuracy: 0.9013
# Epoch 41/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.3012 - accuracy: 0.9193
# Epoch 41: saving model to ft_weights/checkpoints\cp-41.ckpt
# 2262/2262 [==============================] - 364s 161ms/step - loss: 0.3012 - accuracy: 0.9193 - val_loss: 0.4043 - val_accuracy: 0.9013
# Epoch 42/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.2825 - accuracy: 0.9251
# Epoch 42: saving model to ft_weights/checkpoints\cp-42.ckpt
# 2262/2262 [==============================] - 364s 161ms/step - loss: 0.2825 - accuracy: 0.9251 - val_loss: 0.3801 - val_accuracy: 0.9097
# Epoch 43/67
# 2262/2262 [==============================] - ETA: 0s - loss: 0.2604 - accuracy: 0.9339
# Epoch 43: saving model to ft_weights/checkpoints\cp-43.ckpt
# 2262/2262 [==============================] - 361s 160ms/step - loss: 0.2604 - accuracy: 0.9339 - val_loss: 0.4225 - val_accuracy: 0.8951

# %% [markdown]
# # 8. Plotting the learning curves

# %%
loss = history.history['loss'] + fhistory.history['loss']
val_loss = history.history['val_loss'] + fhistory.history['val_loss']
accuracy = history.history['accuracy'] + fhistory.history['accuracy']
val_accuracy = history.history['val_accuracy'] + fhistory.history['val_accuracy']

# %% [markdown]
# ### Loss Graph

# %%
plt.figure(figsize=(6,6))
plt.plot(loss,color='r',label='Training Error')
plt.plot(val_loss, color='b',label='Validation Error')
plt.legend()
plt.show()

# %% [markdown]
# ### Accuracy Graph

# %%
plt.figure(figsize=(6,6))
plt.plot(accuracy,color='r',label='Training Accuracy')
plt.plot(val_accuracy, color='b',label='Validation Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # 9. Evaluating the model on the Test Set

# %%
test_loss, test_accuracy = model.evaluate(test_ds, verbose=0)
print("Loss on test set: {}".format(test_loss))
print("Accuracy on test set: {:.4f}%".format(test_accuracy*100))
# Out:
# Loss on test set: 0.34422796964645386
# Accuracy on test set: 91.9611%

# %% [markdown]
# # 10. Plotting the Confusion Matrix

# %%
y_true = []
y_predicted = []
bads =[]
images = []
for image,label in test_ds:
    for i in label:
        y_true.append(i.numpy())
    for i in model.predict(image,verbose=0):
       y_predicted.append(np.argmax(i)) 
    for i in image:
        images.append(image)
for i in range(len(images)):
    if y_true[i] != y_predicted[i]:
        bads.append(images[i])
y_true = np.array(y_true)
y_predicted = np.array(y_predicted)
cm = confusion_matrix(y_true, y_predicted)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=class_names)
disp.plot()
plt.show()
print(len(bads))
# Out:
# 94

# %% [markdown]
# # 11. Saving the final model

# %%
model.save('model/model.h5')

# %% [markdown]
# # 12. Making test predictions

# %%
image = tf.keras.utils.load_img('Test_Image/test3.jpg')
input_arr = tf.keras.utils.img_to_array(image)
input_arr = np.array([input_arr])
input_arr = tf.image.resize(input_arr,(224,224))
predictions = model.predict(input_arr,verbose=0)
score = tf.nn.softmax(predictions[0])
predicted_class = class_names[np.argmax(predictions)]
print('Bird is most likely a {} \nProbability = {:.2f}%'.format(predicted_class,100*np.max(score)))
# Out:
# Bird is most likely a Rufous Treepie
# Probability = 100.00%
